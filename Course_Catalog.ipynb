# %%
from rdflib import Graph, Namespace, URIRef, Literal
import csv

# Define namespaces
ex = Namespace("http://example.org/")
rdf = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
rdfs = Namespace("http://www.w3.org/2000/01/rdf-schema#")

# Bind namespaces outside the function
course_graph = Graph()
course_graph.bind("ex", ex)
course_graph.bind("rdfs", rdfs)

# Function to populate course data from CSV
def populate_course_from_csv(csv_file):
    with open(csv_file, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            # Create course URI
            course_uri = ex[row['Key'].replace(' ', '_')]
            
            course_graph.add((course_uri, rdf.type, ex.Course))
            course_graph.add((course_uri, ex.CourseName, Literal(row['Title'])))
            course_graph.add((course_uri, ex.Faculty, Literal(row['Faculty'])))
            course_graph.add((course_uri, ex.CourseLevel, Literal(row['Course code'])))
            course_graph.add((course_uri, ex.CourseNumber, Literal(row['Course number'])))
            course_graph.add((course_uri, ex.Credits, Literal(row['Level'])))
            course_graph.add((course_uri, ex.Description, Literal(row['Description'])))
            course_graph.add((course_uri, ex.Department, Literal(row['Department'])))
            course_graph.add((course_uri, ex.Type, Literal(row['Type'])))
            course_graph.add((course_uri, ex.WebpageLink, Literal(row['Website'])))
    
    return course_graph

if __name__ == "__main__":
    # Populate course data from CSV
    course_graph = populate_course_from_csv('CATALOG.csv')
    print(course_graph.serialize(format='turtle'))
# Out:
# @prefix ex: <http://example.org/> .
#
# ex:FAS_0173 a ex:Course ;
#     ex:CourseLevel "FTRA" ;
#     ex:CourseName "Traduction littÃ©raire du franÃ§ais Ã  lâ€™anglais" ;
#     ex:CourseNumber "301" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Ã‰tudes franÃ§aises" ;
#     ex:Description "travaux pratiques " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_0174 a ex:Course ;
#     ex:CourseLevel "FTRA" ;
#     ex:CourseName "Traduction littÃ©raire de lâ€™anglais au franÃ§ais" ;
#     ex:CourseNumber "304" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Ã‰tudes franÃ§aises" ;
#     ex:Description "travaux pratiques " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_0175 a ex:Course ;
#     ex:CourseLevel "FTRA" ;
#     ex:CourseName "Traduction littÃ©raire avancÃ©e : du franÃ§ais Ã  lâ€™anglais" ;
#     ex:CourseNumber "401" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Ã‰tudes franÃ§aises" ;
#     ex:Description "travaux pratiques " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_0176 a ex:Course ;
#     ex:CourseLevel "FTRA" ;
#     ex:CourseName "Traduction littÃ©raire avancÃ©e : de lâ€™anglais au franÃ§ais" ;
#     ex:CourseNumber "402" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Ã‰tudes franÃ§aises" ;
#     ex:Description "travaux pratiques " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_0396 a ex:Course ;
#     ex:CourseLevel "ANTH" ;
#     ex:CourseName "Social Economy & Sustainable Futures" ;
#     ex:CourseNumber "450" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Sociology and Anthropology" ;
#     ex:Description "Community Service Learning & Group project" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Community-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_0838 a ex:Course ;
#     ex:CourseLevel "CHEM" ;
#     ex:CourseName "Introduction to Quantum Theory" ;
#     ex:CourseNumber "333" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Chemistry and Biochemistry" ;
#     ex:Description "he course introduces students to the concept of quantum mechanics and the electronic structure of atoms and molecules. Topics include the origins and postulates of quantum theory, the SchrÃ¶dinger equation and applications to simple systems such as the harmonic oscillator, rigid rotor and the hydrogen atom. The course looks at the quantum mechanical treatment of the chemical bond and provides an introduction to spectroscopy." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1 a ex:Course ;
#     ex:CourseLevel "AHSC" ;
#     ex:CourseName "Self-Managed Learning" ;
#     ex:CourseNumber "225" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Applied Human Sciences" ;
#     ex:Description "Enables students to create clear personal visions, set relevant learning goals, create, organize related activities, & assess their progress" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_10 a ex:Course ;
#     ex:CourseLevel "AHSC" ;
#     ex:CourseName "Fieldwork Practice" ;
#     ex:CourseNumber "435" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Applied Human Sciences" ;
#     ex:Description "Fieldwork, lead one small task or learning group in a community, an organizational or an institutional setting" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Work-integrated;Community-based" ;
#     ex:WebpageLink "" .
#
# ex:FAS_100 a ex:Course ;
#     ex:CourseLevel "COMS" ;
#     ex:CourseName "Communication Media: Sound III" ;
#     ex:CourseNumber "477" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Communication Studies" ;
#     ex:Description "Practicum course" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1000 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "African Popular Culture" ;
#     ex:CourseNumber "368" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "History" ;
#     ex:Description "This course explores the varied terrain of African popular culture in the 19th and 20th centuries.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1001 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "History Through Visual Media and Material Culture" ;
#     ex:CourseNumber "379" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "History" ;
#     ex:Description "This course explores the relationship between the public and the past by examining issues in the production, distribution, and reception of history via these new and changing technologies." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1002 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "The Politics of the Past" ;
#     ex:CourseNumber "381" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "History" ;
#     ex:Description "This course examines the uses of history and the role of the historian in the political arena, focusing on cases in which the past has underwritten social movements or mediated public controversies." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1003 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "Selected Topics in Public History" ;
#     ex:CourseNumber "387" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "History" ;
#     ex:Description "Specific topics for this course, and relevant prerequisites, are stated in the Undergraduate Class Schedule." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1004 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "Urban History Laboratory" ;
#     ex:CourseNumber "390" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "History" ;
#     ex:Description "Students conduct original archival and/or oral history research on a selected aspect of Montrealâ€™s history and then go public with their research in creative and engaging ways." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1005 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "History and Sound" ;
#     ex:CourseNumber "397" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "History" ;
#     ex:Description "This course examines sound as a historical subject and a medium for understanding the past. The course may include training in the production of radio documentaries, urban sound walks, and audio podcasts." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1006 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "Methodology and History" ;
#     ex:CourseNumber "403" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "History" ;
#     ex:Description "This course examines the variety of sources, methods, and modes of analysis used in the research and writing of history. It addresses both theoretical and practical aspects of method." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1007 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "Advanced Topics in Public History" ;
#     ex:CourseNumber "481" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "History" ;
#     ex:Description "Advanced seminar in a selected topic in public history. In addition to weekly discussions of relevant readings, the emphasis is on encouraging students to conduct historical investigation on their own, under a professorâ€™s guidance.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1008 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "Public History Internship" ;
#     ex:CourseNumber "486" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "History" ;
#     ex:Description "This internship in public history is designed to allow students to test and hone their skills in a nonâ€‘academic situation.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1009 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "Masterâ€™s Thesis" ;
#     ex:CourseNumber "685" ;
#     ex:Credits "Graduate" ;
#     ex:Department "History" ;
#     ex:Description "Master's Thesis" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_101 a ex:Course ;
#     ex:CourseLevel "COMS" ;
#     ex:CourseName "Communication Media: Moving Images III" ;
#     ex:CourseNumber "484" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Communication Studies" ;
#     ex:Description "Practicum course" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1010 a ex:Course ;
#     ex:CourseLevel "HIST" ;
#     ex:CourseName "Thesis Research" ;
#     ex:CourseNumber "890" ;
#     ex:Credits "Graduate" ;
#     ex:Department "History" ;
#     ex:Description "Thesis Research" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1011 a ex:Course ;
#     ex:CourseLevel "WSDB " ;
#     ex:CourseName "Directed Research" ;
#     ex:CourseNumber "496" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Simone de Beauvoir Institute" ;
#     ex:Description "Practical, hands-on exercises" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1012 a ex:Course ;
#     ex:CourseLevel "WSDB " ;
#     ex:CourseName "Seminar in Womenâ€™s Studies" ;
#     ex:CourseNumber "498" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Simone de Beauvoir Institute" ;
#     ex:Description "Practical, hands-on exercises" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1013 a ex:Course ;
#     ex:CourseLevel "WSDB " ;
#     ex:CourseName "Introduction to Historical Perspectives in Womenâ€™s Studies" ;
#     ex:CourseNumber "290" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Simone de Beauvoir Institute" ;
#     ex:Description "This course provides an introduction to theories and writing that affect the lives of women. Through the writing of feminist authors, students examine, from mainly the 20th century, the development of feminist theories and debate.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1014 a ex:Course ;
#     ex:CourseLevel "WSDB " ;
#     ex:CourseName "Introduction to Contemporary Concerns in Womenâ€™s Studies" ;
#     ex:CourseNumber "291" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Simone de Beauvoir Institute" ;
#     ex:Description "This course explores a range of current issues and debates within feminism. Using interdisciplinary feminist theories that consider how systems of power such as patriarchy, capitalism, racism, and heterosexism constitute one another, it examines particular local and global topics of interest/concern which may include health, education, work, violence against women, globalization, militarism, media and cultural representations, families, and feminist activism." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1015 a ex:Course ;
#     ex:CourseLevel "WSDB " ;
#     ex:CourseName "Health Issues: Feminist Perspectives" ;
#     ex:CourseNumber "391" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Simone de Beauvoir Institute" ;
#     ex:Description "This course presents feminist, intersectional, postcolonialist, poststructuralist and queer examinations of a variety of womenâ€™s health issues.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1016 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Honours Seminar" ;
#     ex:CourseNumber "470" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "With the permission of the Department, a student may arrange a tutorial program with a faculty member." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1017 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "The Creative Process" ;
#     ex:CourseNumber "224" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "This course introduces students to some options for developing their own process of literary creation, from the ENGLISH development of an idea through to the writing and editing of works of prose fiction, poetry, and/or drama." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1018 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Literary Pedagogies" ;
#     ex:CourseNumber "601" ;
#     ex:Credits "Graduate" ;
#     ex:Department "English" ;
#     ex:Description "Special Topics in English Literature" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1019 a ex:Course ;
#     ex:CourseLevel "PHIL" ;
#     ex:CourseName "Deductive Logic" ;
#     ex:CourseNumber "214" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Philosophy" ;
#     ex:Description "This course presents the modern symbolic systems of sentential and predicate logic. Students transcribe English sentences into a logical form, analyze the concepts of logical truth, consistency, and validity, as well as learn to construct derivations in each system." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1020 a ex:Course ;
#     ex:CourseLevel "PHIL" ;
#     ex:CourseName "Introduction to the Philosophy of Science" ;
#     ex:CourseNumber "220" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Philosophy" ;
#     ex:Description "This course provides an introduction to the main problems in the philosophy of science. These include the structure of scientific theories, various models of scientific method and explanation, and the existence of unobservables." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1021 a ex:Course ;
#     ex:CourseLevel "PHIL" ;
#     ex:CourseName "Introduction to Ethics" ;
#     ex:CourseNumber "232" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Philosophy" ;
#     ex:Description "In this course, students are introduced to some representative approaches to ethical thought and action." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1022 a ex:Course ;
#     ex:CourseLevel "PHIL" ;
#     ex:CourseName "Presocratics and Plato" ;
#     ex:CourseNumber "260" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Philosophy" ;
#     ex:Description "This course is a study of ancient Greek philosophy from its beginnings to Plato." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1023 a ex:Course ;
#     ex:CourseLevel "PHIL" ;
#     ex:CourseName "Aristotle and Hellenistic Philosophy" ;
#     ex:CourseNumber "261" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Philosophy" ;
#     ex:Description "This course is an introduction to Aristotle and the main lines of thought in Hellenistic philosophy, including Stoicism, Epicureanism and Scepticism." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1024 a ex:Course ;
#     ex:CourseLevel "PHIL" ;
#     ex:CourseName "Introduction to Epistemology" ;
#     ex:CourseNumber "263" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Philosophy" ;
#     ex:Description "An introduction to the basic concepts and problems in epistemology, including belief, knowledge, scepticism, perception, and intentionality." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1025 a ex:Course ;
#     ex:CourseLevel "PHIL" ;
#     ex:CourseName "Introduction to Metaphysics" ;
#     ex:CourseNumber "265" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Philosophy" ;
#     ex:Description "This course is an introduction to metaphysics and the attempt to understand a mindâ€‘independent reality.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1026 a ex:Course ;
#     ex:CourseLevel "POLI " ;
#     ex:CourseName "Introduction to International Relations" ;
#     ex:CourseNumber "205" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Political science" ;
#     ex:Description "This course introduces the principal theories, concepts, and debates in the contemporary study of international relations. It provides an overview of issues in international security, international political economy and global governance." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1027 a ex:Course ;
#     ex:CourseLevel "POLI" ;
#     ex:CourseName "Human Rights: An Overview" ;
#     ex:CourseNumber "214" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Political science" ;
#     ex:Description "Â This course introduces students to the historical origins of the concept of human rights; the international regime and the acceptance of several generations of rights such as civil and political rights, economic rights, group rights, and womenâ€™s rights; the critiques of universalism and the problems of implementation of human rights." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Community-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1028 a ex:Course ;
#     ex:CourseLevel "POLI" ;
#     ex:CourseName "Notâ€‘forâ€‘Profit Organizations and the Law" ;
#     ex:CourseNumber "300" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Political science" ;
#     ex:Description "This course introduces students to the legal regimes affecting notâ€‘forâ€‘ profit organizations (NPO). The course covers the legal structures, rules and procedures that govern NPOs, the vast diversity of NPOs, and practical questions such as how to set up an NPO." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1029 a ex:Course ;
#     ex:CourseLevel "POLI" ;
#     ex:CourseName "International Organizations" ;
#     ex:CourseNumber "315" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Political science" ;
#     ex:Description "This course offers an overview of international institutions and global governance. It examines major theoretical perspectives on international organizations, and addresses the role of the United Nations system, regional organizations, and nonâ€‘governmental organizations in promoting international coâ€‘operation to address collective problems." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_103 a ex:Course ;
#     ex:CourseLevel "COMS" ;
#     ex:CourseName "Communication Media: Advanced Topics" ;
#     ex:CourseNumber "493" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Communication Studies" ;
#     ex:Description "Practicum course" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1030 a ex:Course ;
#     ex:CourseLevel "POLI" ;
#     ex:CourseName "Public Policy and the Politics of Equality" ;
#     ex:CourseNumber "328" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Political science" ;
#     ex:Description "This course reviews theoretical debates about the role of the state and the individual, collective and individual rights, integration, and the role of cultural diversity and identity. It examines selected policy demands of women, the poor, refugees, and other constituencies." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1031 a ex:Course ;
#     ex:CourseLevel "POLI " ;
#     ex:CourseName "Approaches to Social Science Inquiry" ;
#     ex:CourseNumber "392" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Political science" ;
#     ex:Description "This course introduces students to a variety of approaches to social scientific inquiry, focusing on their underlying logics. The course covers variableâ€‘based research of the qualitative and quantitative variety and alternatives to this approach such as critical theory, processâ€‘tracing, modelling, ethnography, interpretivist analysis, and conceptual analysis." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1032 a ex:Course ;
#     ex:CourseLevel "" ;
#     ex:CourseName "Arts and Science Federation of Associations" ;
#     ex:CourseNumber "" ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Largest faculty association, representing over 16,000 undergraduate Arts and Science students." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1033 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "School of Community and Public Affairs Studentsâ€™ Association" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "School of Community and Public Affairs" ;
#     ex:Description "The SCPASA provides advocacy for students of the School of Community and Public Affairs" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1034 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Liberal Arts SocietyÂ " ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Liberal Arts College" ;
#     ex:Description "LAS represents students who are majoring and minoring in the Western Society and Culture program of the Liberal Arts College of Concordia" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1035 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Chemistry and Biochemistry Graduate Students Association" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Chemistry and Biochemistry" ;
#     ex:Description "Graduate student association for MSc and PhD students in the Department of Chemistry and Biochemistry" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1036 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Student Association for Graduates in English (SAGE)" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "English" ;
#     ex:Description "SAGE's purpose is to enrich the academic, creative, and social life of all MA and Ph.D. students enrolled in the English graduate program." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1037 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "IPSA-Concordia Summer School in Applied Diplomacy" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "Policy-oriented seminars will be complemented with a practical hands-on Diplomacy Lab, allowing the participants to work on case studies in teams.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "https://www.concordia.ca/summer/artsci/ipsa-applied-diplomacy.html" .
#
# ex:FAS_1038 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Projected Futures 5: Experimental Science Journalism Studies" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "Projected Futures 5Â is an intensive and experiential summer school that will challenge participants to rethink how science is communicated with society. Graduate students will be exposed to the foundations of evidence-based science journalism and then asked to experiment to create new forms of scientific storytelling." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "https://www.concordia.ca/artsci/journalism/programs/journalism-studies.html" .
#
# ex:FAS_1039 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Azrieli Institute of Israel Studies" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "A common passion and dedication to the study of Israel brings together faculty, researchers and students from diverse fields such as archaeology, religion, political science, economics, arts and literature, and anthropology and sociology." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_104 a ex:Course ;
#     ex:CourseLevel "COMS" ;
#     ex:CourseName "Cultures of Production" ;
#     ex:CourseNumber "513" ;
#     ex:Credits "Graduate" ;
#     ex:Department "Communication Studies" ;
#     ex:Description "Field research projects" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1040 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Centre for Interdisciplinary Studies in Society and Culture" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "The Centre for Interdisciplinary Studies in Society and Culture is Concordiaâ€™s home for discussion, exchange, and collaborative research across the humanities and the arts." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "https://www.concordia.ca/artsci/cissc.html" .
#
# ex:FAS_1041 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Loyola Sustainability Research Centre" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "The mission of the Loyola Sustainability Research Centre (LSRC)Â is to promote a transdisciplinary approach to research and education about relationships among natural, human, and technological systems through basic and applied research, research creation, and art and design.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "https://www.concordia.ca/artsci/research/loyola-sustainability.html" .
#
# ex:FAS_1042 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Centre for Applied Synthetic Biology (CASB)" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "Concordiaâ€™s Centre for Applied Synthetic Biology is Canadaâ€™s first and only research centre dedicated to the development of foundational technologies in synthetic biology and their application to solve emerging needs in environmental protection, sustainable manufacturing, agriculture, food production and drug development.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "https://www.concordia.ca/research/casb.html" .
#
# ex:FAS_1043 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "The Centre for Biological Applications of Mass Spectrometry" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "The Centre for Biological Applications of Mass Spectrometry (CBAMS) is a state-of-the-art facility that supports researchers and provides graduate students enrolled in \"omics\" sciences with valuable hands-on training." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "https://www.concordia.ca/research/mass-spec.html" .
#
# ex:FAS_1044 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "The Centre for Clinical Research in Health" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "The Centre for Clinical Research in Health (CCRH) is devoted to the study of the psychosocial determinants of physical and mental health." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "https://www.concordia.ca/research/clinical-research-health.html" .
#
# ex:FAS_1045 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Centre for NanoScience Research" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "The Centre for NanoScience Research provides access toÂ state-of-the-art instrumentation and fosters and promotes interdisciplinary research collaborations in nanoscale science." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "https://www.concordia.ca/research/nanoscience.html" .
#
# ex:FAS_1046 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Centre for Oral History and Digital Storytelling" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "It explores the links between oral history, digital media, the arts and education." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1047 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "The Centre for Research in Human Development" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "The Centre for Research in Human Development (CRDH) brings together top researchers and trainees in the area of lifespan development." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "http://crdh.concordia.ca/homee.html" .
#
# ex:FAS_1048 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Centre for Research in Molecular Modeling" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "CERMM is a multi-institutional research centre that supports research in the molecular sciences, fostering collaborations between researchers in all fields of molecular simulations, including chemistry, biology, physics and engineering." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1049 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Centre for Sensory Studies" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The Centre for Sensory Studies is an interdisciplinary collaboration platform for research in the social life and history of the senses, multisensory aesthetics, sensory design and marketing, and the development of technologies for expanding the sensorium in innovative ways." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_105 a ex:Course ;
#     ex:CourseLevel "COMS" ;
#     ex:CourseName "Media Production: Sound" ;
#     ex:CourseNumber "562" ;
#     ex:Credits "Graduate" ;
#     ex:Department "Communication Studies" ;
#     ex:Description "Lectures and Laboratory: average 6 hours per week" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1050 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Centre for Structural and Functional Genomics" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "A state-of-the-art core genomics facility and computational resources to sequence, process and store the genetic information of various organisms." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1051 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "The Center for Studies in Behavioral Neurobiology" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The Center for Studies in Behavioral Neurobiology (CSBN) brings together the talents of scientists interested in probing the fundamental brain mechanisms that underlie behavior and disease." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1052 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "The Centre for the Study of Learning and Performance" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The mission of the CSLP is to conduct research on teaching and learning processes." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1053 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Centre for Broadcasting and Journalism Studies" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The Concordia Centre for Broadcasting and Journalism Studies has been involved with the study of media since 1981, as a research centre and as an archive. The Centre prides itself as a hub of intellectual engagement with media by sociologists, journalism and communication scholars, historians, and literature specialists." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1054 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Centre for the Study of Politics and Immigration" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "The CSPI is a research initiative on the politics of immigration and on immigration-related public policies. It produces and supports original research, provides training to students and is engaged in knowledge dissemination." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "https://www.concordia.ca/artsci/research/cspi.html" .
#
# ex:FAS_1055 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Technoculture, Art and Games (TAG)" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Technoculture, Art and GamesÂ (TAG) is an interdisciplinary centre for research/creation in game studies and design, digital culture and interactive art." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1056 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Karl Polanyi Institute of Political Economy" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The mission of the Institute is two-fold: to preserve the intellectual legacy of Karl Polanyi and to contribute to research andÂ  policy debates on new development strategies locally and internationally and on the new or reformed multilateral institutions required for the global order." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1057 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Institute for Genocide and Human Rights Studies (MIGS)" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The institute serves as a leadership and ideas incubator that convenes stakeholders with the goal of developing better policies to protect human rights.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1058 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Microscopy and Cellular Imaging" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The Centre for Microscopy and Cell Imaging provides members of Concordia University with access toÂ advanced fluorescence microscopes." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1059 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Montreal Health Statistics Centre" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The Montreal Health Statistics Centre (MHS) connects Statistics students and faculty with health researchers. Through training, networking and collaboration, we promote best practices and methodologies relevant to health research." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_106 a ex:Course ;
#     ex:CourseLevel "COMS" ;
#     ex:CourseName "Media Production: Intermedia" ;
#     ex:CourseNumber "570" ;
#     ex:Credits "Graduate" ;
#     ex:Department "Communication Studies" ;
#     ex:Description "Lectures and Laboratory: average 6 hours per week" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1060 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Institute for Investigative Journalism" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The Institute for Investigative Journalism (IIJ) offers unparalleled educational experiences for journalism students and in-depth coverage of complex stories in underserved communities. IIJ connects major media outlets with journalism students and faculty from across the nation to carry out investigations in the public interest." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1061 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Social Justice Centre" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "The Social Justice Centre provides support for events, offers fellowships for postdoctoral researchers and graduate students and promotes dialogue and collaboration between researchers with different backgrounds and methodologies." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "https://www.concordia.ca/artsci/research/social-justice-centre.html" .
#
# ex:FAS_1062 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Center for Research on Values, Attitudes and Societies" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Graduate" ;
#     ex:Department "Any department" ;
#     ex:Description "TheÂ Center for Research on Values, Attitudes and SocietiesÂ aims to study the evolution of values and attitudes among societies, in Canada and throughout the world." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "https://www.concordia.ca/artsci/research/cevas-en.html" .
#
# ex:FAS_1063 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia Centre for Cognitive Science and Linguistics" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The Concordia Centre for Cognitive Science and Linguistics provides a structure for the intellectual exchange and sharing of resources among scholars at Concordia University and other institutions who are interested in the study of the mind.Â " ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1064 a ex:Course ;
#     ex:CourseLevel "WSDB" ;
#     ex:CourseName "Feminist Perspectives on Culture" ;
#     ex:CourseNumber "491" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Simone de Beauvoir Institute" ;
#     ex:Description "This seminar explores the central concepts and theories in feminist cultural studies, as they inform feminist, postâ€‘colonial, queer, and postâ€‘structuralist understandings of culture." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1065 a ex:Course ;
#     ex:CourseLevel "SSDB" ;
#     ex:CourseName "Seminar in Advanced Topics in Sexuality I" ;
#     ex:CourseNumber "492" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Simone de Beauvoir Institute" ;
#     ex:Description "This seminar is designed to provide a setting for concentrated learning and an opportunity for advanced feminist and intersectional study on a research topic in sexuality." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1066 a ex:Course ;
#     ex:CourseLevel "" ;
#     ex:CourseName "Lab for Latin American and Caribbean Studies" ;
#     ex:CourseNumber "" ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Our multidisciplinary faculty and student members work together to give students research related experience that they can't get in the classroom. We bring in speakers from around the world, organize events, and publish together. Students at all levels get to network with established scholars, practice presenting research, and be involved in publishing." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Research-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1067 a ex:Course ;
#     ex:CourseLevel "" ;
#     ex:CourseName "Humanities+" ;
#     ex:CourseNumber "" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Any department" ;
#     ex:Description "Humanities+ is a skills development + work-integrated learning (WIL) experience program that offers students in Humanities-based programs a unique opportunity to prepare for life after graduation. The program is offered in partnership with FutureBound and Career and Planning Services (CAPS)." ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Work-integrated;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_1068 a ex:Course ;
#     ex:CourseLevel "FTRA" ;
#     ex:CourseName """Initiation au sous-titrage
# Co-listÃ© : FTRA 538""" ;
#     ex:CourseNumber "538" ;
#     ex:Credits "Graduate" ;
#     ex:Department "Ã‰tudes franÃ§aises" ;
#     ex:Description "volet pratique" ;
#     ex:Faculty "FAS" ;
#     ex:Type "" ;
#     ex:WebpageLink "" .
#
# ex:FAS_107 a ex:Course ;
#     ex:CourseLevel "COMS" ;
#     ex:CourseName "Media Research Practicum" ;
#     ex:CourseNumber "606" ;
#     ex:Credits "Graduate" ;
#     ex:Department "Communication Studies" ;
#     ex:Description "Individual research practicum offered on a tutorial basis under faculty supervision" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_108 a ex:Course ;
#     ex:CourseLevel "ECON" ;
#     ex:CourseName "Applied Econometrics" ;
#     ex:CourseNumber "423" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Economics" ;
#     ex:Description "computer analysis; case studies; model building" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_109 a ex:Course ;
#     ex:CourseLevel "ECON" ;
#     ex:CourseName "Econometric Theory I" ;
#     ex:CourseNumber "680" ;
#     ex:Credits "Graduate" ;
#     ex:Department "Economics" ;
#     ex:Description "computer-based applications" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_11 a ex:Course ;
#     ex:CourseLevel "AHSC" ;
#     ex:CourseName "Community Development I" ;
#     ex:CourseNumber "443" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Applied Human Sciences" ;
#     ex:Description "Community" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated;Community-based;" ;
#     ex:WebpageLink "" .
#
# ex:FAS_110 a ex:Course ;
#     ex:CourseLevel "ECON" ;
#     ex:CourseName "Applied Econometrics: Microeconometrics" ;
#     ex:CourseNumber "683" ;
#     ex:Credits "Graduate" ;
#     ex:Department "Economics" ;
#     ex:Description "practical aspects of analysis" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_12 a ex:Course ;
#     ex:CourseLevel "AHSC" ;
#     ex:CourseName "Advanced Family Life Education" ;
#     ex:CourseNumber "456" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Applied Human Sciences" ;
#     ex:Description "Fieldwork, 1 hour per week of observation in a family life education setting" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_13 a ex:Course ;
#     ex:CourseLevel "AHSC" ;
#     ex:CourseName "Basic Human Relations Laboratory" ;
#     ex:CourseNumber "470" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Applied Human Sciences" ;
#     ex:Description "Laboratory" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_139 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Introductory Creative Writing: Poetry" ;
#     ex:CourseNumber "225" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "Writing workshop (peer critique, revision, ongoing development)" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_14 a ex:Course ;
#     ex:CourseLevel "AHSC" ;
#     ex:CourseName "Independent Study I" ;
#     ex:CourseNumber "490" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Applied Human Sciences" ;
#     ex:Description "Field studies, and/or research" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_140 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Introductory Creative Writing: Prose Fiction" ;
#     ex:CourseNumber "226" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "Writing workshop (peer critique, revision, ongoing development)" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_141 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Introductory Creative Writing: Playwriting" ;
#     ex:CourseNumber "227" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "Writing workshop (peer critique, revision, ongoing development)" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_142 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Creative Writing: Prose Fiction" ;
#     ex:CourseNumber "342" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "Writing workshop (peer critique, revision, ongoing development)" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_143 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Creative Non-Fiction Writing" ;
#     ex:CourseNumber "347" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "Writing workshop (peer critique, revision, ongoing development)" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_144 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Creative Writing: Poetry" ;
#     ex:CourseNumber "348" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "Writing workshop (peer critique, revision, ongoing development)" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_145 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Advanced Studies in Creative Writing" ;
#     ex:CourseNumber "429" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "Writing workshop (peer critique, revision, ongoing development)" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_146 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Professional Development Workshops" ;
#     ex:CourseNumber "802" ;
#     ex:Credits "Graduate" ;
#     ex:Department "English" ;
#     ex:Description "Workshops" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_147 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "Literary Production: Curating and Archiving the Literary Event" ;
#     ex:CourseNumber "415" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "Students aid in the development and maintenance of a related blog and an archive of current and previous reading series" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_148 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
#     ex:CourseName "The Solo Play" ;
#     ex:CourseNumber "416" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "English" ;
#     ex:Description "Writing workshop (peer critique, revision, ongoing development)" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_15 a ex:Course ;
#     ex:CourseLevel "AHSC" ;
#     ex:CourseName "Independent Study II" ;
#     ex:CourseNumber "491" ;
#     ex:Credits "Undergraduate" ;
#     ex:Department "Applied Human Sciences" ;
#     ex:Description "Field studies, and/or research" ;
#     ex:Faculty "FAS" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:FAS_150 a ex:Course ;
#     ex:CourseLevel "ENGL" ;
# ...
#
# ex:OTHER_41 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Canadian Students for Sensible Drug Policy" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "A grassroots network comprised of youth/students who are concerned about the negative impact of drug policies." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_42 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia Canadian Asian Society (CCAS)" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The Concordia Canadian Asian Society is a non-profit association representing the Asian culture within the Montreal community." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_43 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia Dragon Boat Club" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Amateur Dragon Boat team from Concordia University" ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_44 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia E-Sports Student Association" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "CESA is looking to gather Concordia's gaming enthusiasts." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_45 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia Mycological Society" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The club promotes scientific and educational activities related to fungi and fosters the appreciation of wild and cultivated mushrooms." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_46 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia Ski & Snowboard Club" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Concordia Ski & Snowboard Club (CSSC) is a student-run organization that plans 15+ different ski trips and events each year." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_47 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia University Tamil Mantram (CUTAM)" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Tamil is a language, a heritage, a culture, an ethnicity - an identity. To strengthen and share this identity is our mandate." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_48 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia University Turkish Student Association" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "A non-profit organization aiming to gather all Turkish Students together and give information about Turkish culture." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_49 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Delegation Concordia aux Jeux de la Communication" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Rejoignez la delegation de l'Universite Concordia aux Jeux franco-canadiens de la communication." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_5 a ex:Course ;
#     ex:CourseLevel "FRAN" ;
#     ex:CourseName "Le franÃ§ais des affaires I" ;
#     ex:CourseNumber "318" ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Ce cours vise Ã  faire acquÃ©rir des compÃ©tences nÃ©cessaires Ã  une communication Ã©crite et orale efficace dans des situations complexes du marchÃ© du travail." ;
#     ex:Faculty "Other" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_50 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Filipino Organization of Concordia University Students" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Motivated by the need to emphasize the visibility and representation of the Filipino culture at Concordia University." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_51 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Haitian Students at Concordia (HSAC)" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "HSAC is an organization run by Haitian students with a focus on educating students of Concordia about Haitian culture." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_52 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Hillel Concordia" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Hillel Concordia is dedicated to enriching the lives of Jewish students on and off campus." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_53 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Hive Cafe, Solidarity Cooperative" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Cafe providing healthy and affordable food to students and the community." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_54 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Muslim Student Association" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "MSA facilitates the lives of Muslim students by providing a variety of services namely prayer spaces, organized prayers, seminars and other activities." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_55 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Otaku Anime of Concordia University" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "A club where students are able to gather during their free time to meet others who are interested in Japanese animation." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_56 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Roller Skating Club" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "A club for students who want to express themselves through roller skating, make connections, and help others improve their roller-skating skills." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_57 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Socialist Fightback Association" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Socialist Fightback is present at Concordia and McGill universities in Montreal; it aims to promote Marxist ideas among students and workers." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_58 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Thaqalayn Muslim Association" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "TMS is a student organization that aims to spread the teachings of Islam through the Holy Prophet Muhammad, the Qur'an & Ahlulbayt." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_59 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "International and Ethnic Associations Council" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "IEAC's mission is to solidify relationships among students and other associations." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_6 a ex:Course ;
#     ex:CourseLevel "FRAN" ;
#     ex:CourseName "Le franÃ§ais des affaires II" ;
#     ex:CourseNumber "319" ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Ce cours vise Ã  faire acquÃ©rir des compÃ©tences nÃ©cessaires Ã  une communication Ã©crite et orale efficace dans des situations complexes du marchÃ© du travail." ;
#     ex:Faculty "Other" ;
#     ex:Type "Course-integrated" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_60 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Centre for Gender Advocacy" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Promoting gender equality and empowerment, particularly as it relates to marginalized communities." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_61 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Community University Television - Concordia" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "CUTV - Concordia's Television Station" ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_62 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia Cinema Politica Student Association" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Politica film screening series" ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_63 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia Community Solidarity Co-op Bookstore" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Alternative education/bookstore" ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_64 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia Greenhouse" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The Concordia Greenhouse Project is a collectively run, consensus-based, non-profit organization. It uses the Henry H. Hall Building rooftop greenhouse as an all-organic space geared towards community, education and sustainable horticulture." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_65 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Concordia Studentsâ€™ Nightline" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "An anonymous, confidential, and non-judgmental active listening service" ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_66 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "CURE Concordia" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "CURE is rooted in an anti-oppression analysis and a community-driven social-justice research model." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_67 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "ENGCOMM" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Engineering and Commerce Case Competition" ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_68 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Garnet Key Society" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Concordia University's official honour society that acts as a liaison between the Office of the President and the student body." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_69 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Peopleâ€™s Potato" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Community soup kitchen" ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_70 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Quebec public interest research group of Concordia" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Resource centre for student and community research and organizing that aims to connect the campus to grassroots community struggles." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_71 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Right To Move" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Volunteer-run non-profit bike shop that allows students and members of the community to fix their own bicycles with the help of volunteers." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_72 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Sustainability Action Fund" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "The Sustainability Action Fund (SAF) is a student run fee levy group at Concordia University. The majority of funding goes to support projects to develop sustainable infrastructure, urban agriculture, community-building, and education surrounding environmental and community issues, with the long-term goal of inspiring and developing a culture of sustainability at Concordia University." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_73 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Sustainable Concordia" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Sustainable Concordia is a fee levy group registered as a non-profit organization. Our mission is to push for a sustainable culture at Concordia." ;
#     ex:Faculty "Other" ;
#     ex:Type "Student life" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_74 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "Lab for Latin American and Caribbean Studies" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "Our multidisciplinary faculty and student members work together to give students research related experience that they can't get in the classroom. We bring in speakers from around the world, organize events, and publish together. Students at all levels get to network with established scholars, practice presenting research, and be involved in publishing." ;
#     ex:Faculty "Other" ;
#     ex:Type "Research-based" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_8 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "D3 Residence Program" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "13 week full-time internship" ;
#     ex:Faculty "Other" ;
#     ex:Type "Course-integrated;Work-integrated;" ;
#     ex:WebpageLink "" .
#
# ex:OTHER_9 a ex:Course ;
#     ex:CourseLevel "Â " ;
#     ex:CourseName "D3 Innovation Projects" ;
#     ex:CourseNumber "Â " ;
#     ex:Credits "Any level" ;
#     ex:Department "Any department" ;
#     ex:Description "3 month full-time internship" ;
#     ex:Faculty "Other" ;
#     ex:Type "Course-integrated;Work-integrated;" ;
#     ex:WebpageLink "" .

# %%
turtle_content = course_graph.serialize(format="turtle")

# Write the Turtle content to a file
with open("Course_Catalog.ttl", "w") as f:
    f.write(turtle_content)

# %%
from rdflib import Graph
from rdflib.plugins.sparql import prepareQuery


# Define the SPARQL query
query = """
PREFIX ex: <http://example.org/>

SELECT ?courseLevel
WHERE {
  # ?course a ex:Course ;
          ex:Faculty "FAS" ;
          ex:Department "Simone de Beauvoir Institute" ;
          ex:CourseLevel ?courseLevel .
}
"""

# Prepare the SPARQL query
q = prepareQuery(query)

# Execute the query and print the results
for row in course_graph.query(q):
    print(row.courseLevel)
# Out:
# 496
# 498
# 290
# 291
# 391
# 491
# 292
# 394
# 494
# 492
# 428
# 428
# 220
# 275
# 425
# 426
