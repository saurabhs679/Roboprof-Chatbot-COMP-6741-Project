# %%
from rdflib import Graph, Namespace
from rdflib.plugins.sparql import prepareQuery

# Load the Turtle file
g = Graph()
g.parse("merged_output.ttl", format="turtle")

# Define the SPARQL query
query = prepareQuery("""
    PREFIX ex: <http://example.org/>
    SELECT DISTINCT ?course ?provenance (COUNT(?topic) as ?total_occurrences)
    WHERE {
      # ?topic a ex:Topic ;
             ex:TopicName "Recursion" ;
             ex:provenance ?provenance ;
             ex:topic_in_course ?course ;
             ex:topic_in_lecture ?lecture.
      
    
      # ?topicInCourse ex:topic_in_course ?course ;
                     ex:topic_in_lecture ?lecture .
      BIND(?topicInCourse AS ?topicCourse)
    } GROUP BY ?course ?provenance ?lecture 
""")

# Execute the query and process the results
results = g.query(query)

# Sort the results in descending order based on total_occurrences
sorted_results = sorted(results, key=lambda row: int(row.total_occurrences), reverse=True)

# Print the sorted results
for row in sorted_results:
    print("Course:", row.course)
    print("Event:", row.provenance)
    print("Total Occurrences:", row.total_occurrences)
    print()
# Out:
# Course: http://example.org/COMP_6481
# Event: Tutorial3
# Total Occurrences: 8
#
# Course: http://example.org/COMP_6481
# Event: lecture
# Total Occurrences: 8
#
# Course: http://example.org/COMP_6481
# Event: Tutorial3
# Total Occurrences: 7
#
# Course: http://example.org/COMP_6481
# Event: lecture
# Total Occurrences: 7

# %%
query = prepareQuery(
    """
    PREFIX ex: <http://example.org/>

    SELECT DISTINCT ?dbpediaLink ?topicName ?provenance ?topicInLecture
    WHERE {
      # ?topic ex:topic_in_course ex:COMP_6481 ;
             ex:dbpediaLink ?dbpediaLink ;
             ex:TopicName ?topicName ;
             ex:provenance ?provenance ;
             ex:topic_in_lecture ?topicInLecture .
    }
    """
)

# Execute the query and print the results
for row in g.query(query):
    print("DBpedia Link:", row.dbpediaLink)
    print("Topic Name:", row.topicName)
    print("Provenance:", row.provenance)
    print("Topic in Lecture:", row.topicInLecture)
    print()
# Out:
# DBpedia Link: https://dbpedia.org/page/Category:Algorithms
# Topic Name: Algorithm efficiency
# Provenance: Course outline
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: https://dbpedia.org/page/Binary_tree
# Topic Name: Binary Trees
# Provenance: Course outline
# Topic in Lecture: http://example.org/Trees
#
# DBpedia Link: https://dbpedia.org/page/Depth-first_search
# Topic Name: Depth First Search (DFS)
# Provenance: Course outline
# Topic in Lecture: http://example.org/Graphs
#
# DBpedia Link: https://dbpedia.org/page/Hash_table
# Topic Name: Hash table
# Provenance: Course outline
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: https://dbpedia.org/page/Object-oriented_programming
# Topic Name: Inheritance
# Provenance: Course outline
# Topic in Lecture: http://example.org/Introduction
#
# DBpedia Link: https://www.wikidata.org/wiki/Q15825362
# Topic Name: Run Time Errors
# Provenance: Course outline
# Topic in Lecture: http://example.org/Exception_Handelling
#
# DBpedia Link: https://dbpedia.org/page/Tail_call
# Topic Name: Tail Recursion
# Provenance: Course outline
# Topic in Lecture: http://example.org/Recursion
#
# DBpedia Link: http://dbpedia.org/resource/ADT_Inc.
# Topic Name: ADT
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/ADT_Inc.
# Topic Name: ADT
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/ADT_Inc.
# Topic Name: ADT
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/ADT_Inc.
# Topic Name: ADT
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Automatic_vehicle_location
# Topic Name: AVL
# Provenance: Tutorial5
# Topic in Lecture: http://example.org/Trees_Tutorial5
#
# DBpedia Link: http://dbpedia.org/resource/Bachelor_of_Science
# Topic Name: BS
# Provenance: lecture
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: http://dbpedia.org/resource/British_Summer_Time
# Topic Name: BST
# Provenance: Tutorial5
# Topic in Lecture: http://example.org/Trees_Tutorial5
#
# DBpedia Link: http://dbpedia.org/resource/Cartilage_oligomeric_matrix_protein
# Topic Name: COMP
# Provenance: lecture
# Topic in Lecture: http://example.org/Recursion
#
# DBpedia Link: http://dbpedia.org/resource/Central_processing_unit
# Topic Name: CPU
# Provenance: lecture
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: http://dbpedia.org/resource/Central_Florida
# Topic Name: Central Florida
# Provenance: lecture
# Topic in Lecture: http://example.org/Graphs
#
# DBpedia Link: http://dbpedia.org/resource/Computer_science
# Topic Name: Computer Science
# Provenance: lecture
# Topic in Lecture: http://example.org/Graphs
#
# DBpedia Link: http://dbpedia.org/resource/Nintendo_DS
# Topic Name: DS
# Provenance: lecture
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: http://dbpedia.org/resource/Derive_(computer_algebra_system)
# Topic Name: Derive
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Edge_(wrestler)
# Topic Name: Edge
# Provenance: lecture
# Topic in Lecture: http://example.org/Graphs
#
# DBpedia Link: http://dbpedia.org/resource/For_Inspiration_and_Recognition_of_Science_and_Technology
# Topic Name: FIRST
# Provenance: lecture
# Topic in Lecture: http://example.org/Recursion
#
# DBpedia Link: http://dbpedia.org/resource/Shafi_Goldwasser
# Topic Name: Goldwasser
# Provenance: lecture
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: http://dbpedia.org/resource/Shafi_Goldwasser
# Topic Name: Goldwasser
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/BM-21_Grad
# Topic Name: Grad
# Provenance: lecture
# Topic in Lecture: http://example.org/Introduction
#
# DBpedia Link: http://dbpedia.org/resource/HIM_(Finnish_band)
# Topic Name: HIM
# Provenance: lecture
# Topic in Lecture: http://example.org/Recursion
#
# DBpedia Link: http://dbpedia.org/resource/Hash_function
# Topic Name: Hash Function
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Hash_table
# Topic Name: Hashtable
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Is-a
# Topic Name: IS-A
# Provenance: lecture
# Topic in Lecture: http://example.org/Introduction
#
# DBpedia Link: http://dbpedia.org/resource/Java_virtual_machine
# Topic Name: JVM
# Provenance: lecture
# Topic in Lecture: http://example.org/Exception_Handelling
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial1
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial1
# Topic in Lecture: http://example.org/Exception_Handelling
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial1
# Topic in Lecture: http://example.org/Exception_Handelling_Tutorial1
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial1
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial1
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial1
# Topic in Lecture: http://example.org/Introduction
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial1
# Topic in Lecture: http://example.org/Introduction_Tutorial4
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial1
# Topic in Lecture: http://example.org/Recursion
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Exception_Handelling
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Exception_Handelling_Tutorial1
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Introduction
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Introduction_Tutorial4
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Recursion
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial4
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial4
# Topic in Lecture: http://example.org/Exception_Handelling
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial4
# Topic in Lecture: http://example.org/Exception_Handelling_Tutorial1
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial4
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial4
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial4
# Topic in Lecture: http://example.org/Introduction
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial4
# Topic in Lecture: http://example.org/Introduction_Tutorial4
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: Tutorial4
# Topic in Lecture: http://example.org/Recursion
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: lecture
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: lecture
# Topic in Lecture: http://example.org/Exception_Handelling
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: lecture
# Topic in Lecture: http://example.org/Exception_Handelling_Tutorial1
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: lecture
# Topic in Lecture: http://example.org/Introduction
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: lecture
# Topic in Lecture: http://example.org/Introduction_Tutorial4
#
# DBpedia Link: http://dbpedia.org/resource/Java
# Topic Name: Java
# Provenance: lecture
# Topic in Lecture: http://example.org/Recursion
#
# DBpedia Link: http://dbpedia.org/resource/Koko_the_Clown
# Topic Name: Koko
# Provenance: lecture
# Topic in Lecture: http://example.org/Introduction
#
# DBpedia Link: http://dbpedia.org/resource/New_York_University
# Topic Name: NYU
# Provenance: lecture
# Topic in Lecture: http://example.org/Graphs
#
# DBpedia Link: http://dbpedia.org/resource/Pitfall!
# Topic Name: PITFALL
# Provenance: lecture
# Topic in Lecture: http://example.org/Recursion
#
# DBpedia Link: http://dbpedia.org/resource/Physical_vapor_deposition
# Topic Name: PVD
# Provenance: lecture
# Topic in Lecture: http://example.org/Graphs
#
# DBpedia Link: http://dbpedia.org/resource/Preorder
# Topic Name: Preorder
# Provenance: lecture
# Topic in Lecture: http://example.org/Graphs
#
# DBpedia Link: http://dbpedia.org/resource/Primate
# Topic Name: Primate
# Provenance: lecture
# Topic in Lecture: http://example.org/Introduction
#
# DBpedia Link: http://dbpedia.org/resource/Priority_queue
# Topic Name: Priority Queue
# Provenance: Tutorial2
# Topic in Lecture: http://example.org/Graphs_Tutorial2
#
# DBpedia Link: http://dbpedia.org/resource/Quadratic
# Topic Name: Quadratic
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Quadratic_function
# Topic Name: Quadratic
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Quicksort
# Topic Name: Quick Sort
# Provenance: Tutorial5
# Topic in Lecture: http://example.org/Trees_Tutorial5
#
# DBpedia Link: http://dbpedia.org/resource/Quicksort
# Topic Name: Quicksort
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Southern_Illinois_University
# Topic Name: Southern Illinois University
# Provenance: lecture
# Topic in Lecture: http://example.org/Graphs
#
# DBpedia Link: http://dbpedia.org/resource/Timsort
# Topic Name: Timsort
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/SM_U-10_(Austria-Hungary)
# Topic Name: U X
# Provenance: lecture
# Topic in Lecture: http://example.org/Graphs
#
# DBpedia Link: http://dbpedia.org/resource/Unicode
# Topic Name: Unicode
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Washington_(state)
# Topic Name: Washington
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Martell_Webster
# Topic Name: Webster
# Provenance: lecture
# Topic in Lecture: http://example.org/Introduction
#
# DBpedia Link: http://dbpedia.org/resource/Wiley-Blackwell
# Topic Name: Wiley
# Provenance: lecture
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: http://dbpedia.org/resource/Wiley-Blackwell
# Topic Name: Wiley
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Microsoft_Windows
# Topic Name: Windows
# Provenance: lecture
# Topic in Lecture: http://example.org/Algorithm_analysis
#
# DBpedia Link: http://dbpedia.org/resource/Byte
# Topic Name: byte
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Hash_function
# Topic Name: hash
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap
#
# DBpedia Link: http://dbpedia.org/resource/Partition_of_a_set
# Topic Name: partition
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Recursion
# Topic Name: Recursion
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Recursion
# Topic Name: Recursion
# Provenance: Tutorial3
# Topic in Lecture: http://example.org/Recursion
#
# DBpedia Link: http://dbpedia.org/resource/Recursion
# Topic Name: Recursion
# Provenance: lecture
# Topic in Lecture: http://example.org/Hashmap_Tutorial3
#
# DBpedia Link: http://dbpedia.org/resource/Recursion
# Topic Name: Recursion
# Provenance: lecture
# Topic in Lecture: http://example.org/Recursion

# %%
from rdflib import Graph, Literal, URIRef
from rdflib.plugins.sparql import prepareQuery

# Load your RDF data
g = Graph()
g.parse("merged_output.ttl", format="turtle")  # Replace "merged_output.ttl" with your RDF file path



# Define the SPARQL query
query = """
    PREFIX ex: <http://example.org/>

    SELECT DISTINCT ?course ?provenance ?lecture
    WHERE {
        # ?topic a ex:Topic ;
               ex:TopicName "Java" ;
               ex:topic_in_course ?course ;
               ex:provenance ?provenance ;
               ex:topic_in_lecture ?lecture .
    }
"""

# Execute the query
results = g.query(query)

# Print the results
for row in results:
    print(f"Topic is covered in course {row['course']} -> {row['provenance']} -> {row['lecture']}")
# Out:
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial1 -> http://example.org/Algorithm_analysis
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial1 -> http://example.org/Exception_Handelling
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial1 -> http://example.org/Exception_Handelling_Tutorial1
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial1 -> http://example.org/Hashmap
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial1 -> http://example.org/Hashmap_Tutorial3
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial1 -> http://example.org/Introduction
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial1 -> http://example.org/Introduction_Tutorial4
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial1 -> http://example.org/Recursion
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial3 -> http://example.org/Algorithm_analysis
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial3 -> http://example.org/Exception_Handelling
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial3 -> http://example.org/Exception_Handelling_Tutorial1
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial3 -> http://example.org/Hashmap
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial3 -> http://example.org/Hashmap_Tutorial3
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial3 -> http://example.org/Introduction
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial3 -> http://example.org/Introduction_Tutorial4
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial3 -> http://example.org/Recursion
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial4 -> http://example.org/Algorithm_analysis
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial4 -> http://example.org/Exception_Handelling
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial4 -> http://example.org/Exception_Handelling_Tutorial1
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial4 -> http://example.org/Hashmap
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial4 -> http://example.org/Hashmap_Tutorial3
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial4 -> http://example.org/Introduction
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial4 -> http://example.org/Introduction_Tutorial4
# Topic is covered in course http://example.org/COMP_6481 -> Tutorial4 -> http://example.org/Recursion
# Topic is covered in course http://example.org/COMP_6481 -> lecture -> http://example.org/Algorithm_analysis
# Topic is covered in course http://example.org/COMP_6481 -> lecture -> http://example.org/Exception_Handelling
# Topic is covered in course http://example.org/COMP_6481 -> lecture -> http://example.org/Exception_Handelling_Tutorial1
# Topic is covered in course http://example.org/COMP_6481 -> lecture -> http://example.org/Hashmap
# Topic is covered in course http://example.org/COMP_6481 -> lecture -> http://example.org/Hashmap_Tutorial3
# Topic is covered in course http://example.org/COMP_6481 -> lecture -> http://example.org/Introduction
# Topic is covered in course http://example.org/COMP_6481 -> lecture -> http://example.org/Introduction_Tutorial4
# Topic is covered in course http://example.org/COMP_6481 -> lecture -> http://example.org/Recursion

# %%
query_str = """
PREFIX ex: <http://example.org/>

SELECT DISTINCT ?provenance
WHERE {
  # ?topic a ex:Topic ;
         ex:provenance ?provenance .
  FILTER NOT EXISTS {
    # ?topic ex:TopicName "2D" ;
           ex:provenance ?provenance .
  }
}
"""

# Prepare the SPARQL query
query = prepareQuery(query_str)

# Execute the query
missing_provenance = []
for row in g.query(query):
    missing_provenance.append(row.provenance)

# Print the missing provenance
print("Provenance not available for 2D:", missing_provenance)
# Out:
# Provenance not available for 2D: [rdflib.term.Literal('Course outline'), rdflib.term.Literal('Tutorial3'), rdflib.term.Literal('lecture'), rdflib.term.Literal('Tutorial5'), rdflib.term.Literal('worksheet'), rdflib.term.Literal('Tutorial1'), rdflib.term.Literal('Tutorial4'), rdflib.term.Literal('Tutorial2')]
